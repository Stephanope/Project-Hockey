# %% [markdown]
# # Data acquisition
# *Ce notebook va chercher les données depuis l'API et il explicite aussi où sont stockées les données*

# %%
from ift6758.data import fetch_all_seasons_regular

# %% [markdown]
# *La cellule ci-dessous prend beaucoup de temps à run, c'est normal*

# %%
fetch_all_seasons_regular(2016,2023)
# Out:
# Erreur 404 lors du téléchargement.
# Arrêt à la partie 1231, fin de la saison détectée.
# Erreur 404 lors du téléchargement.
# Arrêt à la partie 1272, fin de la saison détectée.
# Erreur 404 lors du téléchargement.
# Arrêt à la partie 1272, fin de la saison détectée.
# Erreur 404 lors du téléchargement.
# Arrêt à la partie 1083, fin de la saison détectée.
# Erreur 404 lors du téléchargement.
# Arrêt à la partie 869, fin de la saison détectée.
# Erreur 404 lors du téléchargement.
# Arrêt à la partie 1313, fin de la saison détectée.
# Erreur 404 lors du téléchargement.
# Arrêt à la partie 1313, fin de la saison détectée.
# Erreur 404 lors du téléchargement.
# Arrêt à la partie 1313, fin de la saison détectée.

# %%
# TODO fetch les donnees pour les playoffs
# Out:
# cwd: C:\Users\Pierre Emery\Documents\Projets\Project-Hockey\notebooks
# ift6758 exists here?: False
# python: C:\Users\Pierre Emery\miniconda3\envs\ift6758-conda-env\python.exe
# sys.path[0]: C:\Users\Pierre Emery\Documents\Projets\Project-Hockey

# %%
# TODO plus tard faudra séparer en training set et testing set
