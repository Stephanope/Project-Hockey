# %% [markdown]
# # Data acquisition
# *Ce notebook va chercher les données depuis l'API et il explicite aussi où sont stockées les données*

# %%
from ift6758.data import fetch_all_seasons_regular

# %% [markdown]
# **On telecharge localement le jeu de données**

# %% [markdown]
# *Attention! La cellule ci-dessous prend beaucoup de temps à run, c'est normal*

# %%
fetch_all_seasons_regular(2016,2021)
# Out:
# Erreur 404 lors du téléchargement.
# Arrêt à la partie 1231, fin de la saison détectée.

# %%
# TODO fetch les donnees pour les playoffs

# %% [markdown]
# *On charge les données brutes pour deux parties seulement pour avoir un aperçu du jeu de donnée*

# %%
from ift6758.data import load_cached_plays_raw_dataframe

df_raw = load_cached_plays_raw_dataframe(2016, game_type=2, max_games=2)
df_raw
# Out:
#          gameId  eventId   typeDescKey  period timeInPeriod  teamId     x  \
# 0    2016020001        5  period-start       1        00:00     NaN   NaN
# 1    2016020001        6       faceoff       1        00:00    10.0   0.0
# 2    2016020001       51      stoppage       1        00:05     NaN   NaN
# 3    2016020001        7       faceoff       1        00:05    10.0  69.0
# 4    2016020001      201      takeaway       1        00:43    10.0 -81.0
# ..          ...      ...           ...     ...          ...     ...   ...
# 642  2016020002      702       faceoff       3        19:41    19.0   0.0
# 643  2016020002      703           hit       3        19:51    16.0  95.0
# 644  2016020002      625  blocked-shot       3        19:59    19.0  57.0
# 645  2016020002      626    period-end       3        20:00     NaN   NaN
# 646  2016020002      630      game-end       3        20:00     NaN   NaN
#
#         y shotType
# 0     NaN     None
# 1     0.0     None
# ...

# %%
# TODO plus tard faudra séparer en training set et testing set
