# %% [markdown]
# # Data Cleaning
# *Ce notebook converti les événements de chaque play en dataframe Pandas pour que ce soit plus réutilisable à l'avenir*

# %%
from ift6758.data import load_cached_seasons_dataframe

# attention ça peut prendre quelques minutes à run!
df_regular = load_cached_seasons_dataframe(2016,2023) # on peut mettre en 3e paramètre 2 si on veut que les games de saisons et 3 si on veut que les games de playoffs
len(df_regular)
# Out:
# 647679

# %%
df_regular
# Out:
#        timeInPeriod  period  eventId teamShot     typeEvent     x     y  \
# 0             01:11       1        8      TOR  shot-on-goal -77.0   5.0
# 1             02:53       1       11      OTT  shot-on-goal  86.0  13.0
# 2             04:01       1       15      OTT  shot-on-goal  23.0 -38.0
# 3             04:46       1       16      OTT  shot-on-goal  33.0 -15.0
# 4             06:46       1       24      TOR  shot-on-goal -34.0  28.0
# ...             ...     ...      ...      ...           ...   ...   ...
# 647674        12:57       3      252      EDM  shot-on-goal  85.0   1.0
# 647675        14:25       3     1183      FLA  shot-on-goal -52.0 -27.0
# 647676        15:23       3     1189      FLA  shot-on-goal -59.0 -29.0
# 647677        15:48       3     1193      EDM  shot-on-goal  57.0 -26.0
# 647678        17:42       3     1215      EDM  shot-on-goal  84.0   3.0
#
#                    shooter             goalie typeShot  openNet goalStrenght  \
# ...
