# %% [markdown]
# # Data Cleaning
# *Ce notebook converti les événements de chaque play en dataframe Pandas pour que ce soit plus réutilisable à l'avenir*

# %%
from ift6758.data import load_cached_seasons_dataframe

df_regular = load_cached_seasons_dataframe(2016,2023,2)
len(df_regular)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 sys.path.append(os.path.abspath('..'))
#       4 from ift6758.data import load_cached_seasons_dataframe
# ----> 6 df_regular = load_cached_seasons_dataframe(2016,2023,2)
#       7 len(df_regular)
#
# File ~\Desktop\Hockey truc\Project-Hockey\ift6758\data\data_exploration.py:305, in load_cached_seasons_dataframe(start_year, end_year, game_type)
#     303 dfs = []
#     304 for y in range(start_year, end_year + 1):
# --> 305     df_y = load_cached_season_dataframe(y, game_type=game_type)
#     306     if not df_y.empty:
#     307         dfs.append(df_y)
#
# File ~\Desktop\Hockey truc\Project-Hockey\ift6758\data\data_exploration.py:291, in load_cached_season_dataframe(year, game_type)
#     288 global home, away, team_by_id, player_name
#     289 home, away, team_by_id, player_name = play_context(game)
# --> 291 df_game = create_plays_dataframe(game["plays"])
#     292 game_id = game.get("id")
#     293 df_game["gameId"] = game_id
#
# File ~\Desktop\Hockey truc\Project-Hockey\ift6758\data\data_exploration.py:236, in create_plays_dataframe(plays)
#     225     goalie_id = details.get('goalieInNetId')
#     226     is_empty_net = (play.get('typeDescKey') == 'goal') and (goalie_id is None)
#     228     clean_data.append({
#     229         'timeInPeriod': play.get('timeInPeriod'),
#     230         'period': (play.get('periodDescriptor') or {}).get('number', '?'),
#     231         'eventId': play.get('eventId'),
#     232         'teamShot': teamShot,
#     233         'typeEvent': play.get('typeDescKey'),
#     234         'x': details.get('xCoord'),
#     235         'y': details.get('yCoord'),
# --> 236         'shooter': get_player_name(shooter_id),
#     237         'goalie': get_player_name(goalie_id),
#     238         'typeShot' : details.get('shotType'),
#     239         'openNet' : is_empty_net,
#     240         'goalStrenght' : get_goal_strength(play)
#     241     })
#     243 new_df = pd.DataFrame(clean_data)
#     244 return new_df
#
# TypeError: get_player_name() missing 1 required positional argument: 'player_name'

# %%
df_regular
# Out:
#        timeInPeriod  period  eventId teamShot     typeEvent     x     y  \
# 0             01:11       1        8      TOR  shot-on-goal -77.0   5.0
# 1             02:53       1       11      OTT  shot-on-goal  86.0  13.0
# 2             04:01       1       15      OTT  shot-on-goal  23.0 -38.0
# 3             04:46       1       16      OTT  shot-on-goal  33.0 -15.0
# 4             06:46       1       24      TOR  shot-on-goal -34.0  28.0
# ...             ...     ...      ...      ...           ...   ...   ...
# 604351        09:00       3      935      LAK  shot-on-goal -73.0 -27.0
# 604352        12:41       3      971      LAK  shot-on-goal -73.0 -21.0
# 604353        17:28       3     1024      LAK  shot-on-goal -27.0 -26.0
# 604354        18:39       3     1039      LAK          goal -74.0   7.0
# 604355        00:06       4     1056      LAK          goal  64.0 -20.0
#
#                    shooter             goalie typeShot  openNet goalStrenght  \
# 0             Mitch Marner     Craig Anderson    wrist    False
# 1              Chris Kelly  Frederik Andersen    wrist    False
# 2                Cody Ceci  Frederik Andersen    wrist    False
# 3            Erik Karlsson  Frederik Andersen     slap    False
# 4          Martin Marincin     Craig Anderson    wrist    False
# ...                    ...                ...      ...      ...          ...
# 604351     Phillip Danault    Arvid Soderblom    wrist    False
# 604352     Quinton Byfield    Arvid Soderblom    wrist    False
# 604353  Vladislav Gavrikov    Arvid Soderblom     slap    False
# 604354    Viktor Arvidsson    Arvid Soderblom    wrist    False           PP
# 604355        Adrian Kempe    Arvid Soderblom     snap    False           EV
#
#             gameId  season  gameType
# 0       2016020001    2016         2
# 1       2016020001    2016         2
# 2       2016020001    2016         2
# 3       2016020001    2016         2
# 4       2016020001    2016         2
# ...            ...     ...       ...
# 604351  2023021312    2023         2
# 604352  2023021312    2023         2
# 604353  2023021312    2023         2
# 604354  2023021312    2023         2
# 604355  2023021312    2023         2
#
# [604356 rows x 15 columns]
