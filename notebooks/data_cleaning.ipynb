# %% [markdown]
# # Data Cleaning
# *Ce notebook converti les événements de chaque play en dataframe Pandas pour que ce soit plus réutilisable à l'avenir*

# %%
from ift6758.data import create_plays_dataframe

# %%
play_df = create_plays_dataframe(all_plays)
play_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 play_df = create_plays_dataframe(all_plays)
#       2 play_df
#
# NameError: name 'all_plays' is not defined

# %%
year = 2023
play_df = load_full_regular_season_dataframe(year, game_type=2, max_games=1312)

play_df.shape, play_df["teamShot"].nunique()
play_df
