# %% [markdown]
# # Data Cleaning
# *Ce notebook converti les événements de chaque play en dataframe Pandas pour que ce soit plus réutilisable à l'avenir*

# %%
from ift6758.data import load_cached_seasons_dataframe

df_regular = load_cached_seasons_dataframe(2016,2023,2)
len(df_regular)
# Out:
# 79983

# %%
df_regular.head(10)
# Out:
#   timeInPeriod  period  eventId teamShot     typeEvent   x   y  \
# 0        01:01       1       63      TBL  shot-on-goal  58 -25
# 1        01:10       1      151      TBL  shot-on-goal  81   8
# 2        01:47       1       70      TBL  shot-on-goal  55  30
# 3        02:57       1      152      TBL  shot-on-goal  58 -30
# 4        07:15       1      239      NSH  shot-on-goal -75 -14
# 5        08:26       1      254      NSH  shot-on-goal -47 -25
# 6        09:24       1      266      TBL  shot-on-goal  34  31
# 7        09:48       1      154      TBL          goal  50 -16
# 8        10:15       1      277      TBL  shot-on-goal  34 -30
# 9        10:37       1      280      TBL  shot-on-goal  63 -21
#
#              shooter           goalie typeShot  openNet goalStrenght  \
# 0     Darren Raddysh      Juuse Saros    wrist    False
# 1      Brayden Point      Juuse Saros   tip-in    False
# 2     Tanner Jeannot      Juuse Saros     snap    False
# 3  Michael Eyssimont      Juuse Saros    wrist    False
# 4       Yakov Trenin  Jonas Johansson     snap    False
# 5    Kiefer Sherwood  Jonas Johansson     snap    False
# 6      Victor Hedman      Juuse Saros    wrist    False
# 7    Nikita Kucherov      Juuse Saros     slap    False           EV
# 8        Erik Cernak      Juuse Saros     snap    False
# 9    Luke Glendening      Juuse Saros    wrist    False
#
#        gameId  season  gameType
# 0  2023020001    2023         2
# 1  2023020001    2023         2
# 2  2023020001    2023         2
# 3  2023020001    2023         2
# 4  2023020001    2023         2
# 5  2023020001    2023         2
# 6  2023020001    2023         2
# 7  2023020001    2023         2
# 8  2023020001    2023         2
# 9  2023020001    2023         2
