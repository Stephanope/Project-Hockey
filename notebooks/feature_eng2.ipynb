# %%
from ift6758.data import load_cached_seasons_dataframe, load_cached_season_dataframe, new_variables

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_training = load_cached_seasons_dataframe(2016,2019) 
df_test = load_cached_season_dataframe(2020) # on y touche pas jusqu'à la fin
df_training # petit apperçu
# Out:
#        timeInPeriod  period  eventId teamShot     typeEvent     x     y  \
# 0             01:11       1        8      TOR  shot-on-goal -77.0   5.0
# 1             02:53       1       11      OTT  shot-on-goal  86.0  13.0
# 2             04:01       1       15      OTT  shot-on-goal  23.0 -38.0
# 3             04:46       1       16      OTT  shot-on-goal  33.0 -15.0
# 4             06:46       1       24      TOR  shot-on-goal -34.0  28.0
# ...             ...     ...      ...      ...           ...   ...   ...
# 327337        16:01       3      706      TBL  shot-on-goal -59.0 -24.0
# 327338        17:20       3      709      TBL  shot-on-goal -81.0   3.0
# 327339        18:50       3      713      DAL  shot-on-goal  34.0  -6.0
# 327340        19:27       3      719      DAL  shot-on-goal  31.0  10.0
# 327341        19:45       3      721      DAL  shot-on-goal  77.0   0.0
#
#                 shooter              goalie typeShot  openNet goalStrenght  \
# ...

# %%
df = new_variables(df_training)
df
# Out:
#        timeInPeriod  period  eventId teamShot     typeEvent     x     y  \
# 0             01:11       1        8      TOR  shot-on-goal -77.0   5.0
# 1             02:53       1       11      OTT  shot-on-goal  86.0  13.0
# 2             04:01       1       15      OTT  shot-on-goal  23.0 -38.0
# 3             04:46       1       16      OTT  shot-on-goal  33.0 -15.0
# 4             06:46       1       24      TOR  shot-on-goal -34.0  28.0
# ...             ...     ...      ...      ...           ...   ...   ...
# 327337        16:01       3      706      TBL  shot-on-goal -59.0 -24.0
# 327338        17:20       3      709      TBL  shot-on-goal -81.0   3.0
# 327339        18:50       3      713      DAL  shot-on-goal  34.0  -6.0
# 327340        19:27       3      719      DAL  shot-on-goal  31.0  10.0
# 327341        19:45       3      721      DAL  shot-on-goal  77.0   0.0
#
#                 shooter              goalie typeShot  ...      gameId season  \
# ...

# %% [markdown]
# ## Améliorations possibles
# ### Certains évenements précédents sont des stoppages et n'ont pas de coordonnées, et aussi le temps parfois ne joue pas avec le temps de l'évenement suivant. C'est pour cela qu'on remarque des NaN dans les distances et des -1 dans la différences de temps avec l'évenement précédent.
# ### Il y a quelque chose à faire pour traiter ces cas.
