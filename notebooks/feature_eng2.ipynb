# %%
from ift6758.data import load_cached_seasons_dataframe, load_cached_season_dataframe, new_variables

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_training = load_cached_seasons_dataframe(2016,2019) 
df_test = load_cached_season_dataframe(2020) # on y touche pas jusqu'à la fin
df_training # petit apperçu
# Out:
#        timeInPeriod  gameSeconds  period  eventId teamShot     typeEvent  \
# 0             01:11           71       1        8      TOR  shot-on-goal
# 1             02:53          173       1       11      OTT  shot-on-goal
# 2             04:01          241       1       15      OTT  shot-on-goal
# 3             04:46          286       1       16      OTT  shot-on-goal
# 4             06:46          406       1       24      TOR  shot-on-goal
# ...             ...          ...     ...      ...      ...           ...
# 327337        16:01         3361       3      706      TBL  shot-on-goal
# 327338        17:20         3440       3      709      TBL  shot-on-goal
# 327339        18:50         3530       3      713      DAL  shot-on-goal
# 327340        19:27         3567       3      719      DAL  shot-on-goal
# 327341        19:45         3585       3      721      DAL  shot-on-goal
#
#            x     y          shooter              goalie  ... lastEventY  \
# 0      -77.0   5.0     Mitch Marner      Craig Anderson  ...       11.0
# 1       86.0  13.0      Chris Kelly   Frederik Andersen  ...       -5.0
# 2       23.0 -38.0        Cody Ceci   Frederik Andersen  ...        0.0
# 3       33.0 -15.0    Erik Karlsson   Frederik Andersen  ...       -2.0
# 4      -34.0  28.0  Martin Marincin      Craig Anderson  ...       34.0
# ...      ...   ...              ...                 ...  ...        ...
# 327337 -59.0 -24.0  Anthony Cirelli      Anton Khudobin  ...      -26.0
# 327338 -81.0   3.0    Blake Coleman      Anton Khudobin  ...        6.0
# 327339  34.0  -6.0   John Klingberg  Andrei Vasilevskiy  ...      -16.0
# 327340  31.0  10.0   John Klingberg  Andrei Vasilevskiy  ...      -22.0
# 327341  77.0   0.0     Joe Pavelski  Andrei Vasilevskiy  ...        7.0
#
#         timeSinceLastEvent distanceSinceLastEvent  goalStrenght  \
# 0                      1.0              17.088007            EV
# 1                      5.0              36.715120            EV
# 2                     18.0             102.318131            EV
# 3                     19.0              45.880279            EV
# 4                     16.0              81.221918            EV
# ...                    ...                    ...           ...
# 327337                 3.0             123.016259            SH
# 327338                 2.0               3.162278            SH
# 327339                 8.0              58.855756            EV
# 327340                 5.0              49.678969            EV
# 327341                10.0               9.899495            EV
#
#         friendlySkaters  opposingSkaters  timeInPowerPlay      gameId  season  \
# 0                     5                5                0  2016020001    2016
# 1                     5                5                0  2016020001    2016
# 2                     5                5                0  2016020001    2016
# 3                     5                5                0  2016020001    2016
# 4                     5                5                0  2016020001    2016
# ...                 ...              ...              ...         ...     ...
# 327337                4                5                0  2019030416    2019
# 327338                4                5                0  2019030416    2019
# 327339                6                5                0  2019030416    2019
# 327340                6                5                0  2019030416    2019
# 327341                6                5                0  2019030416    2019
#
#         gameType
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2
# ...          ...
# 327337         3
# 327338         3
# 327339         3
# 327340         3
# 327341         3
#
# [327342 rows x 24 columns]

# %%
df = new_variables(df_training)
df
# Out:
#        timeInPeriod  gameSeconds  period  eventId teamShot     typeEvent  \
# 0             01:11           71       1        8      TOR  shot-on-goal
# 1             02:53          173       1       11      OTT  shot-on-goal
# 2             04:01          241       1       15      OTT  shot-on-goal
# 3             04:46          286       1       16      OTT  shot-on-goal
# 4             06:46          406       1       24      TOR  shot-on-goal
# ...             ...          ...     ...      ...      ...           ...
# 327337        16:01         3361       3      706      TBL  shot-on-goal
# 327338        17:20         3440       3      709      TBL  shot-on-goal
# 327339        18:50         3530       3      713      DAL  shot-on-goal
# 327340        19:27         3567       3      719      DAL  shot-on-goal
# 327341        19:45         3585       3      721      DAL  shot-on-goal
#
#            x     y          shooter              goalie  ... attack_sign  \
# 0      -77.0   5.0     Mitch Marner      Craig Anderson  ...        -1.0
# 1       86.0  13.0      Chris Kelly   Frederik Andersen  ...         1.0
# 2       23.0 -38.0        Cody Ceci   Frederik Andersen  ...         1.0
# 3       33.0 -15.0    Erik Karlsson   Frederik Andersen  ...         1.0
# 4      -34.0  28.0  Martin Marincin      Craig Anderson  ...        -1.0
# ...      ...   ...              ...                 ...  ...         ...
# 327337 -59.0 -24.0  Anthony Cirelli      Anton Khudobin  ...        -1.0
# 327338 -81.0   3.0    Blake Coleman      Anton Khudobin  ...        -1.0
# 327339  34.0  -6.0   John Klingberg  Andrei Vasilevskiy  ...         1.0
# 327340  31.0  10.0   John Klingberg  Andrei Vasilevskiy  ...         1.0
# 327341  77.0   0.0     Joe Pavelski  Andrei Vasilevskiy  ...         1.0
#
#         x_adj y_adj  shotDistance  shotAngle  isGoal  isEmpty isRebound  \
# 0        77.0  -5.0     13.000000  22.619865   False    False         0
# 1        86.0  13.0     13.341664  77.005383   False    False         0
# 2        23.0 -38.0     76.157731  29.931512   False    False         0
# 3        33.0 -15.0     57.974132  14.995079   False    False         0
# 4        34.0 -28.0     61.717096  26.980231   False    False         0
# ...       ...   ...           ...        ...     ...      ...       ...
# 327337   59.0  24.0     38.418745  38.659808   False    False         0
# 327338   81.0  -3.0      8.544004  20.556045   False    False         0
# 327339   34.0  -6.0     55.326305   6.225829   False    False         0
# 327340   31.0  10.0     58.855756   9.782407   False    False         0
# 327341   77.0   0.0     12.000000   0.000000   False    False         0
#
#         angleDifference      speed
# 0                   0.0  17.088007
# 1                   0.0   7.343024
# 2                   0.0   5.684341
# 3                   0.0   2.414752
# 4                   0.0   5.076370
# ...                 ...        ...
# 327337              0.0  41.005420
# 327338              0.0   1.581139
# 327339              0.0   7.356969
# 327340              0.0   9.935794
# 327341              0.0   0.989949
#
# [327342 rows x 34 columns]
