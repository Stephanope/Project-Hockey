# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

img = np.asarray(Image.open('figures/nhl_rink.png').convert('RGB'))

# %%
plt.imshow(img, extent = [-100, 100, -42.5, 42.5])
plt.scatter(0, 0, s=100, c='red', marker='o')
plt.show()

# %%
data = get_game(2023, 2, 1)
all_plays = data['plays']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data = get_game(2023, 2, 1)
#       2 all_plays = data['plays']
#
# NameError: name 'get_game' is not defined

# %%
df = get_positions(2023)
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\stefa\miniconda3
#
#   added / updated specs:
#     - ipywidgets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ipywidgets-8.1.7           |  py313haa95532_0         243 KB
#     jupyterlab_widgets-3.0.15  |  py313haa95532_0         199 KB
#     widgetsnbextension-4.0.14  |  py313haa95532_0         864 KB
#     ------------------------------------------------------------
#                                            Total:         1.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   ipywidgets         pkgs/main/win-64::ipywidgets-8.1.7-py313haa95532_0
#   jupyterlab_widgets pkgs/main/win-64::jupyterlab_widgets-3.0.15-py313haa95532_0
#   widgetsnbextension pkgs/main/win-64::widgetsnbextension-4.0.14-py313haa95532_0
#
#
#
# Downloading and Extracting Packages: ...working...
# widgetsnbextension-4 | 864 KB    |            |   0%
#
# ipywidgets-8.1.7     | 243 KB    |            |   0%
#
#
# jupyterlab_widgets-3 | 199 KB    |            |   0%
#
#
# jupyterlab_widgets-3 | 199 KB    | 8          |   8%
#
# ipywidgets-8.1.7     | 243 KB    | 6          |   7%
# widgetsnbextension-4 | 864 KB    | 1          |   2%
#
#
# jupyterlab_widgets-3 | 199 KB    | ##4        |  24%
#
# ipywidgets-8.1.7     | 243 KB    | #9         |  20%
# widgetsnbextension-4 | 864 KB    | 5          |   6%
#
#
# jupyterlab_widgets-3 | 199 KB    | ####       |  40%
#
# ipywidgets-8.1.7     | 243 KB    | ###2       |  33%
# widgetsnbextension-4 | 864 KB    | #1         |  11%
#
#
# jupyterlab_widgets-3 | 199 KB    | #######2   |  72%
#
# ipywidgets-8.1.7     | 243 KB    | #####9     |  59%
#
#
# jupyterlab_widgets-3 | 199 KB    | ########## | 100%
# widgetsnbextension-4 | 864 KB    | #8         |  19%
#
# ipywidgets-8.1.7     | 243 KB    | ########5  |  86%
#
# ipywidgets-8.1.7     | 243 KB    | ########## | 100%
#
#
# jupyterlab_widgets-3 | 199 KB    | ########## | 100%
#
#
# jupyterlab_widgets-3 | 199 KB    | ########## | 100%
# widgetsnbextension-4 | 864 KB    | ##9        |  30%
# widgetsnbextension-4 | 864 KB    | ####8      |  48%
# widgetsnbextension-4 | 864 KB    | #######2   |  72%
# widgetsnbextension-4 | 864 KB    | ########## | 100%
#
# ipywidgets-8.1.7     | 243 KB    | ########## | 100%
# widgetsnbextension-4 | 864 KB    | ########## | 100%
# widgetsnbextension-4 | 864 KB    | ########## | 100%
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
